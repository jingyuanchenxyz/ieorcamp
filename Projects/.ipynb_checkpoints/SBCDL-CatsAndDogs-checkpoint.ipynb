# %% [markdown]
# # Go wild -- this assignment is to recognize Cats and Dogs. The load dataset function is loading the data properly.
# # Note that the image are in color, i.e., different from the MNIST and Fashion image. The tensors will be different
# # The rest is yours. Here are a few suggestions
#
# # 1. Start with a basic model -- that is your baseline
# # 2. Move a convolutional network
# # 3. Finish with a convolutional network with data augmentation (see the video)

# %%
# USE ONLY IF using a GPU on PACE

# If this is not imported the GPU on the PACE will not function properly
# otherwise, on another system, it will need built with cuda and loaded 
# the same version to work properly
# os.system("module load cuda/12.1.1")
import os
import time
os.system("module load cuda/12.1.1")
time.sleep(20)

# %%
from tensorflow import keras
from keras import layers
from keras.datasets import imdb
import numpy as np
import os, shutil, pathlib
from keras.utils import load_img
from keras.utils import img_to_array
from keras.utils import array_to_img
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
size_picture = 128

# %%
from keras.utils import image_dataset_from_directory

# %%
def tensor_from_image(name):
    img = load_img(name)
    img = img.resize((size_picture,size_picture))
    return (img,img_to_array(img).astype("uint8").reshape((size_picture,size_picture,3)))

# %%
def load_dataset(start_index,end_index):
    images = []
    tensor_inputs = np.zeros((2*(end_index-start_index+1),size_picture,size_picture,3))
    tensor_labels = np.zeros((2*(end_index-start_index+1),1))
    base_directory = pathlib.Path('../datasets/cats_and_dogs/training_set')
    k = 0
    for category in {"cat","dog"}:
        names = [f"{category}.{i}.jpg" for i in range(start_index,end_index+1)]
        for n in names:
            fname = base_directory / category / n
            (img,t) = tensor_from_image(fname)
            images.append(img)
            tensor_inputs[k] = t
            tensor_labels[k] = (category == 'dog')
            k += 1
    return (images,tensor_inputs,tensor_labels)

# %%
def binary_classify(model,inputs,outputs):
  model.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=["accuracy"])
  model.fit(inputs,outputs,epochs=10)

# %%
(training_images,training_inputs,training_labels) = load_dataset(1000,3000)
(testing_images,testing_inputs,testing_labels) = load_dataset(3001,3999)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten

model_basic = Sequential([
    Flatten(input_shape=(size_picture, size_picture, 3)),  # Flattening for dense input
    Dense(128, activation="relu"),
    Dense(64, activation="relu"),
    Dense(1, activation="sigmoid")  # Binary classification
])

binary_classify(model_basic, training_inputs, training_labels)
# Out:
# D:\Jupyter\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.4900 - loss: 2787.1528
# Epoch 2/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.5083 - loss: 197.2255
# Epoch 3/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.4857 - loss: 9.8334
# Epoch 4/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.5058 - loss: 0.7019
# Epoch 5/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.5094 - loss: 0.6908
# Epoch 6/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.5136 - loss: 0.6922
# Epoch 7/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.5038 - loss: 0.6927
# Epoch 8/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4933 - loss: 0.6922
# Epoch 9/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4982 - loss: 0.6921
# Epoch 10/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.5076 - loss: 0.6922
# Epoch 11/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4911 - loss: 0.6914
# Epoch 12/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.4982 - loss: 0.6927
# Epoch 13/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4909 - loss: 0.6921
# Epoch 14/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.5008 - loss: 0.6921
# Epoch 15/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4961 - loss: 0.6921
# Epoch 16/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4974 - loss: 0.6925
# Epoch 17/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4954 - loss: 0.6911
# Epoch 18/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4881 - loss: 0.6925
# Epoch 19/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.5074 - loss: 0.6914
# Epoch 20/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.4784 - loss: 0.6921
# Epoch 21/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.5088 - loss: 0.6923
# Epoch 22/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.5072 - loss: 0.6923
# Epoch 23/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.4909 - loss: 0.6910
# Epoch 24/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0
100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4967 - loss: 0.6920
# Epoch 94/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.5077 - loss: 0.6919
# Epoch 95/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.5052 - loss: 0.6918
# Epoch 96/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4960 - loss: 0.6924
# Epoch 97/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.4876 - loss: 0.6929
# Epoch 98/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4983 - loss: 0.6920
# Epoch 99/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.4933 - loss: 0.6926
# Epoch 100/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.5070 - loss: 0.6915

# %%
from keras.layers import Conv2D, MaxPooling2D

model_cnn = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(size_picture, size_picture, 3)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation="relu"),
    Dense(1, activation="sigmoid")
])

binary_classify(model_cnn, training_inputs, training_labels)
# Out:
# D:\Jupyter\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 140ms/step - accuracy: 0.5669 - loss: 342.6302
# Epoch 2/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.6419 - loss: 2.0219
# Epoch 3/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - accuracy: 0.6959 - loss: 4.7969
# Epoch 4/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.7687 - loss: 0.8943
# Epoch 5/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - accuracy: 0.8306 - loss: 2.6224
# Epoch 6/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.8516 - loss: 1.1981
# Epoch 7/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.7978 - loss: 1.0492
# Epoch 8/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.8537 - loss: 1.4777
# Epoch 9/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.8985 - loss: 1.1226
# Epoch 10/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.8960 - loss: 0.6146

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Augmentation Layers
datagen = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# Input Layer
input = keras.Input(shape=(size_picture, size_picture, 3), name="data")
x = datagen(input)
x = layers.Rescaling(1/255.0)(x)  # Normalize pixel values

# Convolutional Layers
x = Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Flatten()(x)

# Fully Connected Layers
x = Dense(128, activation="relu")(x)
x = Dense(64, activation="relu")(x)
output = Dense(1, activation="sigmoid")(x)

# Build Model
model_augmented = Model(inputs=input, outputs=output)

# Compile & Train
model_augmented.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["accuracy"])
model_augmented.fit(training_inputs, training_labels, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.6158 - loss: 0.6880 - val_accuracy: 0.0000e+00 - val_loss: 1.4828
# Epoch 2/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 154ms/step - accuracy: 0.6482 - loss: 0.6400 - val_accuracy: 0.0624 - val_loss: 1.6812
# Epoch 3/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 154ms/step - accuracy: 0.6706 - loss: 0.6197 - val_accuracy: 0.6929 - val_loss: 0.5768
# Epoch 4/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 153ms/step - accuracy: 0.6840 - loss: 0.5983 - val_accuracy: 0.0025 - val_loss: 4.7351
# Epoch 5/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.6916 - loss: 0.6454 - val_accuracy: 0.5693 - val_loss: 0.5610
# Epoch 6/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 19s 188ms/step - accuracy: 0.6917 - loss: 0.5823 - val_accuracy: 0.5144 - val_loss: 0.8940
# Epoch 7/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 17s 163ms/step - accuracy: 0.7193 - loss: 0.5554 - val_accuracy: 0.1735 - val_loss: 1.7343
# Epoch 8/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - accuracy: 0.6904 - loss: 0.5763 - val_accuracy: 0.7004 - val_loss: 0.5188
# Epoch 9/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 159ms/step - accuracy: 0.7187 - loss: 0.5446 - val_accuracy: 0.7591 - val_loss: 0.4435
# Epoch 10/10
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.6988 - loss: 0.5741 - val_accuracy: 0.9126 - val_loss: 0.2964

# %%
# Model Evaluation
test_loss, test_acc = model_augmented.evaluate(testing_inputs, testing_labels)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.4493 - loss: 0.9340
# Test Accuracy: 0.6331
# Test Loss: 0.6725

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Confusion Matrix Visualization
predictions = (model_augmented.predict(testing_inputs) > 0.5).astype("int32")
cm = confusion_matrix(testing_labels, predictions)

plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Cat", "Dog"], yticklabels=["Cat", "Dog"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step

# %%
# Classification Report
from sklearn.metrics import classification_report
print(classification_report(testing_labels, predictions, target_names=["Cat", "Dog"]))
# Out:
#               precision    recall  f1-score   support
#
#          Cat       0.81      0.35      0.48       999
#          Dog       0.58      0.92      0.72       999
#
#     accuracy                           0.63      1998
#    macro avg       0.70      0.63      0.60      1998
# weighted avg       0.70      0.63      0.60      1998

# %%
# Sample Predictions on Random Test Image
sample_index = np.random.randint(0, len(testing_inputs))
plt.imshow(testing_inputs[sample_index] / 255.0)  # Normalize for visualization
plt.title(f"Model Prediction: {'Dog' if predictions[sample_index][0] == 1 else 'Cat'}")
plt.show()

# %%
# Baseline Model
test_loss_basic, test_acc_basic = model_basic.evaluate(testing_inputs, testing_labels)
print(f"Basic Model - Accuracy: {test_acc_basic:.4f}, Loss: {test_loss_basic:.4f}")

# CNN Model
test_loss_cnn, test_acc_cnn = model_cnn.evaluate(testing_inputs, testing_labels)
print(f"CNN Model - Accuracy: {test_acc_cnn:.4f}, Loss: {test_loss_cnn:.4f}")

# CNN with Augmentation
test_loss_aug, test_acc_aug = model_augmented.evaluate(testing_inputs, testing_labels)
print(f"Augmented CNN Model - Accuracy: {test_acc_aug:.4f}, Loss: {test_loss_aug:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1671 - loss: 0.6952
# Basic Model - Accuracy: 0.5010, Loss: 0.6927
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6215 - loss: 2.5350
# CNN Model - Accuracy: 0.6241, Loss: 2.5650
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.4493 - loss: 0.9340
# Augmented CNN Model - Accuracy: 0.6331, Loss: 0.6725

# %%
import matplotlib.pyplot as plt

models = ["Basic", "CNN", "Augmented CNN"]
accuracies = [test_acc_basic, test_acc_cnn, test_acc_aug]
losses = [test_loss_basic, test_loss_cnn, test_loss_aug]

plt.figure(figsize=(8,5))
plt.bar(models, accuracies, color=["red", "blue", "green"])
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
plt.show()

plt.figure(figsize=(8,5))
plt.bar(models, losses, color=["red", "blue", "green"])
plt.ylabel("Loss")
plt.title("Model Loss Comparison")
plt.show()

# %%
import matplotlib.pyplot as plt

models = ["Basic", "CNN", "Augmented CNN"]
accuracies = [test_acc_basic, test_acc_cnn, test_acc_aug]
losses = [test_loss_basic, test_loss_cnn, test_loss_aug]

plt.figure(figsize=(8,5))
plt.bar(models, accuracies, color=["red", "blue", "green"])
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
plt.show()

plt.figure(figsize=(8,5))
plt.bar(models, losses, color=["red", "blue", "green"])
plt.ylabel("Loss")
plt.title("Model Loss Comparison")
plt.show()

# %%
# Predictions for each model
pred_basic = (model_basic.predict(testing_inputs) > 0.5).astype("int32")
pred_cnn = (model_cnn.predict(testing_inputs) > 0.5).astype("int32")
pred_aug = (model_augmented.predict(testing_inputs) > 0.5).astype("int32")

# Generate confusion matrices
cm_basic = confusion_matrix(testing_labels, pred_basic)
cm_cnn = confusion_matrix(testing_labels, pred_cnn)
cm_aug = confusion_matrix(testing_labels, pred_aug)

# Plot confusion matrices
fig, axes = plt.subplots(1, 3, figsize=(15,5))

for ax, cm, model in zip(axes, [cm_basic, cm_cnn, cm_aug], ["Basic", "CNN", "Augmented CNN"]):
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Cat", "Dog"], yticklabels=["Cat", "Dog"], ax=ax)
    ax.set_title(f"{model} Model")

plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
